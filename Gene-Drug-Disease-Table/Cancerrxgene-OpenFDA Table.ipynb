# %%
from rnaseq_lib.web import openfda_get_drugs_by_query
from rnaseq_lib.web import openfda_drug_label
from rnaseq_lib.web import _rget
from rnaseq_lib.utils.expando import Expando

import pandas as pd
import os
from collections import defaultdict

from progressbar import ProgressBar

# %% [markdown]
# # Table
#
# 1. Get list of drugs and targets from Cancerrxgene
# 2. Check for FDA listing
#     1. Collect indications_of_usage, mechanism_of_action, openfda.brand_name, openfda.generic_name
# 3. Derive tissue from information

# %%
df = pd.read_excel('Cancerrxgene/screened-compounds.xlsx')
print df.shape; df.head()
# Out:
# (265, 5)
#    Drug ID   Drug Name                                           Synonyms  \
# 0        1   Erlotinib  Tarceva, RG-1415, CP-358774, OSI-774, Ro-50823...
# 1        3   Rapamycin  AY-22989, Sirolimus, WY-090217, Torisel, Rapamune
# 2        5   Sunitinib                 Sutent, Sunitinib Malate, SU-11248
# 3        6  PHA-665752                              PHA665752, PHA 665752
# 4        9      MG-132                             LLL cpd, MG 132, MG132
#
#                                 Target                     Target Pathway
# 0                                 EGFR                     EGFR signaling
# 1                               MTORC1                PI3K/MTOR signaling
# 2  PDGFR, KIT, VEGFR, FLT3, RET, CSF1R                      RTK signaling
# 3                                  MET                      RTK signaling
# 4                    Proteasome, CAPN1  Protein stability and degradation

# %% [markdown]
# Query drug name in OpenFDA for additional information

# %%
info = defaultdict(list)

bar = ProgressBar()
for i in bar(xrange(len(df))):
    row = df.iloc[i]
    
    # Collect all aliases for Drug
    aliases = row.Synonyms.split(', ') if type(row.Synonyms) == list else [str(row.Synonyms)]
    aliases = None if 'nan' in aliases[0].lower() else aliases
    drug = [str(row['Drug Name']).split()[0]]
    aliases =  drug + aliases if aliases else drug
    
    # Check if any aliases return OpenFDA results
    r = None
    for name in aliases:
        if not '-' in name:
            r = openfda_drug_label(str(name))
            if r: break
    
    # If no results
    features  = ['usage', 'mech_action', 'brand_name', 'generic_name']
    if not r:
        #print 'No query for: {}'.format(row['Drug Name'])
        for f in features:
            info[f].append(None)
    
    else:
        # Pull out result
        e = r.json(object_hook=Expando)['results'][0]
        
        for f, a in zip(features, ['indications_and_usage', 'mechanism_of_action', 
                         'openfda.brand_name', 'openfda.generic_name']):    
            try:
                attribute = e[a] if not a.startswith('openfda') else e['openfda'][a.split('.')[1]]
                info[f].append('. '.join(attribute))
            except KeyError:
                info[f].append(None)
# Out:
# 100% |########################################################################|

# %% [markdown]
# Add values to dataframe

# %%
df['usage'] = info['usage']
df['mech_action'] = info['mech_action']
df['brand_name'] = info['brand_name']
df['generic_name'] = info['generic_name']

# %%
df.head()
# Out:
#    Drug ID   Drug Name                                           Synonyms  \
# 0        1   Erlotinib  Tarceva, RG-1415, CP-358774, OSI-774, Ro-50823...
# 1        3   Rapamycin  AY-22989, Sirolimus, WY-090217, Torisel, Rapamune
# 2        5   Sunitinib                 Sutent, Sunitinib Malate, SU-11248
# 3        6  PHA-665752                              PHA665752, PHA 665752
# 4        9      MG-132                             LLL cpd, MG 132, MG132
#
#                                 Target                     Target Pathway  \
# 0                                 EGFR                     EGFR signaling
# 1                               MTORC1                PI3K/MTOR signaling
# 2  PDGFR, KIT, VEGFR, FLT3, RET, CSF1R                      RTK signaling
# 3                                  MET                      RTK signaling
# 4                    Proteasome, CAPN1  Protein stability and degradation
#
#                                                usage  \
# 0  1. INDICATIONS AND USAGE Enter section text he...
# 1                                               None
# 2  1 INDICATIONS AND USAGE SUTENT is a kinase inh...
# 3                                               None
# 4                                               None
#
#                                          mech_action brand_name  \
# 0  12.1 Mechanism of Action The mechanism of clin...    Tarceva
# 1                                               None       None
# 2  12.1 Mechanism of Action Sunitinib is a small ...     SUTENT
# 3                                               None       None
# 4                                               None       None
#
#               generic_name
# 0  ERLOTINIB HYDROCHLORIDE
# 1                     None
# 2         SUNITINIB MALATE
# 3                     None
# 4                     None

# %% [markdown]
# Drop rows whose generic or brand name does not match the drug name or synonyms

# %%
rows_to_drop = []
for i in xrange(len(df)):
    row = df.iloc[i]
    aliases = row.Synonyms.split(', ') if type(row.Synonyms) == list else [str(row.Synonyms)]
    drug = [str(row['Drug Name']).split()[0]]
    aliases =  drug + aliases if aliases else drug
    
    # If missing brand and generic name, drop
    if not row.generic_name and not row.brand_name:
        rows_to_drop.append(i)
        continue
    
    # If drug name or synonyms don't match, drop
    if not any([x for x in aliases if x.lower() in row.generic_name.lower()]):
        if not any([x for x in aliases if x.lower() in row.brand_name.lower()]):
            rows_to_drop.append(i)

# %%
df.drop(rows_to_drop)
# Out:
#      Drug ID          Drug Name  \
# 0          1          Erlotinib
# 2          5          Sunitinib
# 5         11         Paclitaxel
# 8         30          Sorafenib
# 10        34           Imatinib
# 12        37         Crizotinib
# 16        51          Dasatinib
# 26        64                CMK
# 27        71      Pyrimethamine
# 35       104         Bortezomib
# 39       119          Lapatinib
# 41       133        Doxorubicin
# 42       134          Etoposide
# 43       135        Gemcitabine
# 45       140        Vinorelbine
# 47       150       Bicalutamide
# 52       155          Ponatinib
# 75       186         Bexarotene
# 76       190          Bleomycin
# 82       199          Pazopanib
# 89       206        Ruxolitinib
# 105      238         Idelalisib
# 107      249       Cabozantinib
# 126      274         Belinostat
# 131      281          Alectinib
# 169     1004        Vinblastine
# 170     1005          Cisplatin
# 171     1006         Cytarabine
# 172     1007          Docetaxel
# 173     1008       Methotrexate
# 174     1009          Tretinoin
# 175     1010          Gefitinib
# 177     1012         Vorinostat
# 178     1013          Nilotinib
# 181     1016       Temsirolimus
# 182     1017           Olaparib
# 184     1019          Bosutinib
# 185     1020       Lenalidomide
# 186     1021           Axitinib
# 196     1032           Afatinib
# 197     1033         Vismodegib
# 210     1054        Palbociclib
# 222     1114          Cetuximab
# 233     1175          Rucaparib
# 236     1199          Tamoxifen
# 253     1372         Trametinib
# 254     1373         Dabrafenib
# 255     1375       Temozolomide
# 256     1377           Afatinib
# 257     1378  Bleomycin (50 uM)
# 259     1495           Olaparib
# 261     1502       Bicalutamide
#
#                                               Synonyms  \
# 0    Tarceva, RG-1415, CP-358774, OSI-774, Ro-50823...
# 2                   Sutent, Sunitinib Malate, SU-11248
# 5    BMS-181339-01, Taxol, Onxol, Paxene, Praxel, A...
# 8                    Nexavar, 284461-73-0, BAY 43-9006
# 10                                    Gleevec, STI-571
# 12          Xalkori, PF2341066, PF-2341066, PF 2341066
# 16                  BMS-354825-03, BMS-354825, Sprycel
# 26                                          KIN001-128
# 27                                Daraprim, Chloridine
# 35                            PS-341, LDP-341, Velcade
# 39                                      Tykerb, Tyverb
# 41   Doxil, Rubex, Adriamycin, Adriablastin, Doxoru...
# 42                   Etopophos, Vepesid, Eposin, VP-16
# 43                                   Gemzar, LY-188011
# 45           vinorelbine tartrate, Navelbine, Exelbine
# 47            ICI-176334, Casodex, Cosudex, ICI 176334
# 52              AP24534, AP-24534, KIN001-192, Iclusig
# 75   LG-100069, Targretin, Targret, Targrexin, Targ...
# 76                                                   -
# 82                                            Votrient
# 89           INCB-18424, Ruxolitinib Phosphate, Jakafi
# 105                                   CAL-101, Zydelig
# 107                       BMS-907351, XL-184, Cometriq
# 126                                    PXD101, PXD-101
# 131                     CH5424802, CH 542802, Alecensa
# 169                                             Velban
# 170  cis-Diammineplatinum(II) dichloride, Platinol,...
# 171         Ara-Cytidine, Arabinosyl Cytosine, U-19920
# 172                                 RP-56976, Taxotere
# 173  Abitrexate, Amethopterin, Rheumatrex, Trexall,...
# 174   ATRA, Vesanoid, Renova, Atralin, Tretin-X, Avita
# 175                                    ZD-1839, Iressa
# 177  Zolinza, SAHA, suberanilohydroxamic acid, sube...
# 178                                   Tasigna, AMN 107
# 181                                   CCI-779, Torisel
# 182                      AZD2281, KU0059436,  Lynparza
# 184                                   SKI-606, Bosulif
# 185                         CDC-501, CC-5013, Revlimid
# 186                                   AG-13736, Inlyta
# 196                          BIBW2992, Tovok, Gilotrif
# 197                                  GDC0449, Erivedge
# 210              PD0332991, PD-0332991, PF-00080665-73
# 222          Erbitux, IMC-C225, C225, IMC-225, L01XC06
# 233         PF-01367338, AG-014699, AG-14447, AG-14699
# 236    Nolvadex, Soltamox, Zynoplex, ICI-46474, Kessar
# 253                               GSK1120212, Mekinist
# 254                               GSK2118436, Tafinlar
# 255               Temodar, Temodal, M-39831, SCH 52365
# 256                          BIBW2992, Tovok, Gilotrif
# 257                                                  -
# 259                      AZD2281, KU0059436,  Lynparza
# 261           ICI-176334, Casodex, Cosudex, ICI 176334
#
#                                                Target  \
# 0                                                EGFR
# 2                 PDGFR, KIT, VEGFR, FLT3, RET, CSF1R
# 5                              Microtubule stabiliser
# 8                              PDGFR, KIT, VEGFR, RAF
# 10                                    ABL, KIT, PDGFR
# 12                                     MET, ALK, ROS1
# 16                      ABL, SRC, Ephrins, PDGFR, KIT
# 26                                               RSK2
# 27                     Dihydrofolate reductase (DHFR)
# 35                                         Proteasome
# 39                                        ERBB2, EGFR
# 41                                      Anthracycline
# 42                                               TOP2
# 43                          Pyrimidine antimetabolite
# 45                           Microtubule destabiliser
# 47                                                 AR
# 52        ABL, PDGFRA, VEGFR2, FGFR1, SRC, TIE2, FLT3
# 75                 Retinioic X receptor (RXR) agonist
# 76                              dsDNA break induction
# 82                        CSF1R, KIT,  PDGFRA, PDGFRB
# 89                                         JAK1, JAK2
# 105                                         PI3Kdelta
# 107  VEGFR, MET, RET, KIT, FLT1, FLT3, FLT4, TIE2,AXL
# 126                                             HDAC1
# 131                                               ALK
# 169                          Microtubule destabiliser
# 170                                   DNA crosslinker
# 171                                    Antimetabolite
# 172                            Microtubule stabiliser
# 173                                    Antimetabolite
# 174                                     Retinoic acid
# 175                                              EGFR
# 177              HDAC inhibitor Class I, IIa, IIb, IV
# 178                                               ABL
# 181                                              MTOR
# 182                                      PARP1, PARP2
# 184                                     SRC, ABL, TEC
# 185                                              CRBN
# 186                                 PDGFR, KIT, VEGFR
# 196                                       ERBB2, EGFR
# 197                                               SMO
# 210                                        CDK4, CDK6
# 222                                              EGFR
# 233                                      PARP1, PARP2
# 236                                              ESR1
# 253                                        MEK1, MEK2
# 254                                              BRAF
# 255                              DNA alkylating agent
# 256                                       ERBB2, EGFR
# 257                             dsDNA break induction
# 259                                      PARP1, PARP2
# 261                                                AR
#
#                         Target Pathway  \
# 0                       EGFR signaling
# 2                        RTK signaling
# 5                              Mitosis
# 8                        RTK signaling
# 10                       RTK signaling
# 12                       RTK signaling
# 16                               Other
# 26                  ERK MAPK signaling
# 27                               Other
# 35   Protein stability and degradation
# 39                      EGFR signaling
# 41                     DNA replication
# 42                     DNA replication
# 43                     DNA replication
# 45                             Mitosis
# 47                     Hormone-related
# 52                       RTK signaling
# 75                               Other
# 76                     DNA replication
# 82                       RTK signaling
# 89                      Other, kinases
# 105                PI3K/MTOR signaling
# 107                     Other, kinases
# 126      Chromatin histone acetylation
# 131                      RTK signaling
# 169                            Mitosis
# 170                    DNA replication
# 171                    DNA replication
# 172                            Mitosis
# 173                    DNA replication
# 174                              Other
# 175                     EGFR signaling
# 177      Chromatin histone acetylation
# 178                      ABL signaling
# 181                PI3K/MTOR signaling
# 182                   Genome integrity
# 184                     Other, kinases
# 185  Protein stability and degradation
# 186                      RTK signaling
# 196                     EGFR signaling
# 197                              Other
# 210                         Cell cycle
# 222                     EGFR signaling
# 233                   Genome integrity
# 236                    Hormone-related
# 253                 ERK MAPK signaling
# 254                 ERK MAPK signaling
# 255                    DNA replication
# 256                     EGFR signaling
# 257                    DNA replication
# 259                   Genome integrity
# 261                    Hormone-related
#
#                                                  usage  \
# 0    1. INDICATIONS AND USAGE Enter section text he...
# 2    1 INDICATIONS AND USAGE SUTENT is a kinase inh...
# 5    INDICATIONS AND USAGE Paclitaxel Injection is ...
# 8    1 INDICATIONS AND USAGE NEXAVAR is a kinase in...
# 10   1 INDICATIONS AND USAGE Imatinib mesylate is a...
# 12   1 INDICATIONS AND USAGE XALKORI is indicated f...
# 16   1 INDICATIONS AND USAGE SPRYCEL® (dasatinib) i...
# 26   Indications and usage Indications and usage: 1...
# 27                                                None
# 35   1 INDICATIONS AND USAGE VELCADE is a proteasom...
# 39   1 INDICATIONS AND USAGE TYKERB® is indicated i...
# 41   1 INDICATIONS AND USAGE Doxorubicin hydrochlor...
# 42   INDICATIONS AND USAGE Etoposide Injection USP ...
# 43   1 INDICATIONS AND USAGE Gemcitabine for Inject...
# 45   1 INDICATIONS AND USAGE Vinorelbine Injection,...
# 47   1 INDICATIONS AND USAGE Bicalutamide 50 mg dai...
# 52   1 INDICATIONS AND USAGE Iclusig (ponatinib) is...
# 75   1 INDICATIONS AND USAGE TARGRETIN® (bexarotene...
# 76   INDICATIONS AND USAGE Bleomycin for injection ...
# 82   1 INDICATIONS AND USAGE VOTRIENT® is indicated...
# 89   1. INDICATIONS AND USAGE Jakafi is a kinase in...
# 105  1 INDICATIONS AND USAGE Zydelig is a kinase in...
# 107  1 INDICATIONS AND USAGE COMETRIQ is indicated ...
# 126  1 INDICATIONS AND USAGE Beleodaq is indicated ...
# 131  1 INDICATIONS AND USAGE ALECENSA is indicated ...
# 169  INDICATIONS AND USAGE: Vinblastine Sulfate Inj...
# 170  INDICATIONS AND USAGE Cisplatin injection is i...
# 171  INDICATIONS AND USAGE Cytarabine in combinatio...
# 172  1. INDICATIONS AND USAGE Docetaxel Injection, ...
# 173  INDICATIONS AND USAGE Neoplastic Diseases Meth...
# 174  1 INDICATIONS AND USAGE Retin-A Micro® (tretin...
# 175  1 INDICATIONS AND USAGE IRESSA is indicated fo...
# 177  1 INDICATIONS AND USAGE ZOLINZA ® is indicated...
# 178  1 INDICATIONS AND USAGE Tasigna is a kinase in...
# 181  1 INDICATIONS AND USAGE TORISEL is indicated f...
# 182  1 INDICATIONS AND USAGE Lynparza is a poly (AD...
# 184  1 INDICATIONS AND USAGE BOSULIF is indicated f...
# 185  1 INDICATIONS AND USAGE REVLIMID is a thalidom...
# 186  1 INDICATIONS AND USAGE INLYTA is indicated fo...
# 196  1 INDICATIONS AND USAGE GILOTRIF is a kinase i...
# 197  1 INDICATIONS AND USAGE ERIVEDGE capsule is in...
# 210  1 INDICATIONS AND USAGE IBRANCE is indicated i...
# 222  1 INDICATIONS AND USAGE Erbitux® is an epiderm...
# 233  1 INDICATIONS AND USAGE Rubraca™ is indicated ...
# 236  INDICATIONS AND USAGE Metastatic Breast Cancer...
# 253  1 INDICATIONS AND USAGE MEKINIST is a kinase i...
# 254  1 INDICATIONS AND USAGE •TAFINLAR is a kinase ...
# 255  1 INDICATIONS AND USAGE TEMODAR is an alkylati...
# 256  1 INDICATIONS AND USAGE GILOTRIF is a kinase i...
# 257  INDICATIONS AND USAGE Bleomycin for injection ...
# 259  1 INDICATIONS AND USAGE Lynparza is a poly (AD...
# 261  1 INDICATIONS AND USAGE Bicalutamide 50 mg dai...
#
#                                            mech_action  \
# 0    12.1 Mechanism of Action The mechanism of clin...
# 2    12.1 Mechanism of Action Sunitinib is a small ...
# 5                                                 None
# 8    12.1 Mechanism of Action Sorafenib is a kinase...
# 10   12.1 Mechanism of Action Imatinib mesylate is ...
# 12   12.1 Mechanism of Action Crizotinib is an inhi...
# 16   12.1 Mechanism of Action Dasatinib, at nanomol...
# 26                                                None
# 27                                                None
# 35   12.1 Mechanism of Action Bortezomib is a rever...
# 39   12.1 Mechanism of Action Lapatinib is a 4-anil...
# 41   12.1 Mechanism of Action The cytotoxic effect ...
# 42                                                None
# 43                                                None
# 45   12.1 Mechanism of Action Vinorelbine is a vinc...
# 47   12.1 Mechanism of Action Bicalutamide is a non...
# 52   12.1 Mechanism of Action Ponatinib is a kinase...
# 75   12.1 Mechanism of Action Bexarotene selectivel...
# 76                                                None
# 82   12.1 Mechanism of Action Pazopanib is a multi-...
# 89   12.1 Mechanism of Action Ruxolitinib, a kinase...
# 105  12.1 Mechanism of Action Idelalisib is an inhi...
# 107  12.1 Mechanism of Action In vitro biochemical ...
# 126  12.1 Mechanism of Action Beleodaq is a histone...
# 131  12.1 Mechanism of Action Alectinib is a tyrosi...
# 169                                               None
# 170                                               None
# 171                                               None
# 172  12.1 Mechanism of Action Docetaxel is an antin...
# 173                                               None
# 174  12.1 Mechanism of Action Although tretinoin ac...
# 175  12.1 Mechanism of Action The epidermal growth ...
# 177  12.1 Mechanism of Action Vorinostat inhibits t...
# 178  12.1 Mechanism of Action Nilotinib is an inhib...
# 181  12.1 Mechanism of Action Temsirolimus is an in...
# 182  12.1 Mechanism of Action Lynparza is an inhibi...
# 184  12.1 Mechanism of Action Bosutinib is a tyrosi...
# 185  12.1 Mechanism of Action Lenalidomide is an an...
# 186  12.1 Mechanism of Action Axitinib has been sho...
# 196  12.1 Mechanism of Action Afatinib covalently b...
# 197  12.1 Mechanism of Action Vismodegib is an inhi...
# 210  12.1 Mechanism of Action Palbociclib is an inh...
# 222  12.1 Mechanism of Action The epidermal growth ...
# 233  12.1 Mechanism of Action Rucaparib is an inhib...
# 236                                               None
# 253  12.1 Mechanism of Action Trametinib is a rever...
# 254  12.1 Mechanism of Action Dabrafenib is an inhi...
# 255  12.1 Mechanism of Action Temozolomide is not d...
# 256  12.1 Mechanism of Action Afatinib covalently b...
# 257                                               None
# 259  12.1 Mechanism of Action Lynparza is an inhibi...
# 261  12.1 Mechanism of Action Bicalutamide is a non...
#
#                                         brand_name  \
# 0                                          Tarceva
# 2                                           SUTENT
# 5                                       paclitaxel
# 8                                          Nexavar
# 10                               imatinib mesylate
# 12                                         Xalkori
# 16                                         SPRYCEL
# 26   THE YEON CMK PORE BLEMISH BC 02 NATURAL BEIGE
# 27                        Pyrimethamine Leucovorin
# 35                                         VELCADE
# 39                                          TYKERB
# 41                       Doxorubicin Hydrochloride
# 42                                       Etoposide
# 43                       GEMCITABINE Hydrochloride
# 45                                     VINORELBINE
# 47                                    Bicalutamide
# 52                                         Iclusig
# 75                                       Targretin
# 76                                       Bleomycin
# 82                                        VOTRIENT
# 89                                          JAKAFI
# 105                                        Zydelig
# 107                                       COMETRIQ
# 126                                       Beleodaq
# 131                                       ALECENSA
# 169                            Vinblastine Sulfate
# 170                                      Cisplatin
# 171                                     Cytarabine
# 172                                      Docetaxel
# 173                                   METHOTREXATE
# 174                                  Retin-A MICRO
# 175                                         IRESSA
# 177                                        ZOLINZA
# 178                                        Tasigna
# 181                                        Torisel
# 182                                       Lynparza
# 184                                        BOSULIF
# 185                                       Revlimid
# 186                                         INLYTA
# 196                                       Gilotrif
# 197                                       ERIVEDGE
# 210                                        Ibrance
# 222                                        ERBITUX
# 233                                        Rubraca
# 236                              Tamoxifen Citrate
# 253                                       Mekinist
# 254                                       Tafinlar
# 255                                        TEMODAR
# 256                                       Gilotrif
# 257                                      Bleomycin
# 259                                       Lynparza
# 261                                   Bicalutamide
#
#                      generic_name
# 0         ERLOTINIB HYDROCHLORIDE
# 2                SUNITINIB MALATE
# 5                      PACLITAXEL
# 8                       SORAFENIB
# 10              IMATINIB MESYLATE
# 12                     CRIZOTINIB
# 16                      DASATINIB
# 26   TITANIUM DIOXIDE, OCTINOXATE
# 27       PYRIMETHAMINE LEUCOVORIN
# 35                     BORTEZOMIB
# 39                      LAPATINIB
# 41      DOXORUBICIN HYDROCHLORIDE
# 42                      ETOPOSIDE
# 43      GEMCITABINE HYDROCHLORIDE
# 45                    VINORELBINE
# 47                   BICALUTAMIDE
# 52        PONATINIB HYDROCHLORIDE
# 75                     BEXAROTENE
# 76                      BLEOMYCIN
# 82        PAZOPANIB HYDROCHLORIDE
# 89                    RUXOLITINIB
# 105                    IDELALISIB
# 107                  CABOZANTINIB
# 126                    BELINOSTAT
# 131       ALECTINIB HYDROCHLORIDE
# 169           VINBLASTINE SULFATE
# 170                     CISPLATIN
# 171                    CYTARABINE
# 172                     DOCETAXEL
# 173                  METHOTREXATE
# 174                     TRETINOIN
# 175                     GEFITINIB
# 177                    VORINOSTAT
# 178                     NILOTINIB
# 181                  TEMSIROLIMUS
# 182                      OLAPARIB
# 184         BOSUTINIB MONOHYDRATE
# 185                  LENALIDOMIDE
# 186                      AXITINIB
# 196                      AFATINIB
# 197                    VISMODEGIB
# 210                   PALBOCICLIB
# 222                     CETUXIMAB
# 233                     RUCAPARIB
# 236             TAMOXIFEN CITRATE
# 253                    TRAMETINIB
# 254                    DABRAFENIB
# 255                  TEMOZOLOMIDE
# 256                      AFATINIB
# 257                     BLEOMYCIN
# 259                      OLAPARIB
# 261                  BICALUTAMIDE
